# %% [markdown]
# # DPatch Attack
# As you might have noticed, there are two different ways to use the CLI. The first one is by passing the arguments directly to the script, and the second one is by using a configuration file. Using a configuration file is a good way to keep track of the experiments you are running, and it is also a good way to avoid passing the same arguments over and over again. This notebook will show you how to use a configuration file and how to pass the arguments directly to the script for the DPatch Attack.

# %% [markdown]
# ## Using a Configuration File

# %% [markdown]
# ### Step 1: Create a Configuration File
#
# As a first step, you need to have a default configuration file. You can create a configuration file by running the following command (from the repository root folder `advsecurenet_mp`):
#
# ```sh
# advsecurenet utils configs get -c dpatch_attack_config.yml -s -o ./default_dpatch_attack_config.yml
# ```
#
# Here, we are also providing the `-o` flag to specify the output directory where the configuration file will be saved. You can also specify the output directory by passing the `-o` flag followed by the path to the directory where you want to save the configuration file. If you don't provide the `-o` flag, the configuration file will be saved in the current working directory with the name `dpatch_attack_config.yml`. If the file already exists, it will be overwritten. If the output path is a directory, the configuration file will be saved in that directory with the name `dpatch_attack_config.yml`.

# %%
# !advsecurenet utils configs get -c dpatch_attack_config.yml -s -o ./default_dpatch_attack_config.yml

# %%
# Let's check the content of the default config file
# !advsecurenet utils configs get -c dpatch_attack_config.yml -p

# %% [markdown]
# ## Step 2: Modify the Configuration File
#
# The default configuration file is capable of running the targeted `DPatch` attack on the small subset of the `COCO` dataset using the `CustomYolov5Model` model. You can modify the configuration file to run the DPatch attack on a different dataset or model - if you add them to the package. You can modify attack parameters, such as the `learning_rate` or `max_iter`. Additionally, you can select whether to use the GPU or CPU for the attack and decide whether to save the adversarial images.
#
# For this example, we will modify the configuration file to run the `DPatch` attack untargeted with `max_iter=2` iterations. We will set the `learning_rate` value to *1.5*. We will also change the object detector to `FasterRCNN`.
#
# You can find the updated configuration file [here](dpatch_attack_config.yml).

# %% [markdown]
# ## Step 3: Run the Attack
#
# Now that you have created and modified the configuration file, you can run the attack by using the following command:
#
# ```sh
# advsecurenet attack dpatch -c dpatch_attack_config.yml
# ```
#
# **Note:** Attack success rate is calculated as the difference in the mean average precision which is the average precision aggregated over all of the classes within the dataset before and after the attack. Since the attack runs on a small subset of the whole dataset, which might not contain enough representatives of each class, the attack success rate might be lower than expected.

# %%
# !advsecurenet attack dpatch -c dpatch_attack_config.yml

# %% [markdown]
# Congratulations! You have successfully run the DPatch Attack using a configuration file. You can now use the configuration file to run the attack with different parameters without having to pass the arguments directly to the script.
